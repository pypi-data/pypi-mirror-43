# %% [markdown]
# # Shapelets and the Shapelet Transform
#
# [github lookup](https://github.com/alan-turing-institute/sktime/blob/dev/examples/Example%20-%20Shapelet%20Transform.ipynb)
#
# Introduced in [1], a shapelet is a time series subsequences that is identified as being representative of class membership. Shapelets are a powerful approach for measuring _phase-independent_ similarity between time series; they can occur at any point within a series and offer _interpretable_ results for how matches occur. The original research extracted shapelets to build a decision tree classifier. As an example, the top shapelet from the <a href="http://timeseriesclassification.com/description.php?Dataset=GunPoint">GunPoint</a> problem found in [1] is shown below (the shapelet is highlighted in red):
#
# ![shapelet gun point](img/shapelets_gun_point.PNG)
#
# The GunPoint problem contains univariate tracking data of actor's wrists as they either take a prop gun from a holster, point it, and return it to the holster, or they simply mime the action without the prop. The classification problem is to detect whether a motion trace is a case of _gun_ or _no gun_. The most discriminatory shapelet shown above offers an interpretable result into how classification decisions can be made; the highlighted red section of the series above is the shapelet and it occurs when an actor returns the gun to the holster. As explained in [1], this is discriminatory because if the gun prop is present then the actor's hand stops suddenly, but if the prop is not present, the actor's hand will not stop abruptly and will subtly continue past their waist due to inertia.
#
# ## The Shapelet Transform
#
# Much research emphasis has been placed on shapelet-based approaches for time series classification (TSC) since the original research was proposed. The current state-of-the-art for shapelets is the **shapelet transform** (ST) [2, 3]. The transform improves upon the original use of shapelets by separating shapelet extraction from the classification algorithm, allowing interpretable phase-independent classification of time series with any standard classification algorithm (such as random/rotation forest, neural networks, nearest neighbour classifications, ensembles of all, etc.). To facilitate this, rather than recursively assessing data for the best shapelet, the transform evaluates candidate shapelets in a single procedure to rank them based on information gain. Then, given a set of _k_ shapelets, a time series can be transformed into _k_ features by calculating the distance from the series to each shapelet. By transforming a dataset in this manner any vector-based classification algorithm can be applied to a shapelet-transformed time series problem while the interpretability of shapelets is maintained through the ranked list of the _best_ shapelets during transformation. An example of the interpretability offered from ST is shown below with the top 10 shapelets extracted from the GunPoint problem in [2]:
#
# ![shapelets gun point transform](img/shapelets_gun_point_transform.PNG)
#
# The image above demonstrates that there are two clear groupings of shapelets: one where the gun is placed into the holster, as in [1], but also one where the gun is removed from the holster. It would be a reasonable assumption that if placing the prob back into the holster is discriminatory then removing it from the holster should also be; this was not detected in the original research but is explicitly identified by using the shapelet transform.
#
# #### References
# [1] Ye, Lexiang, and Eamonn Keogh. "Time series shapelets: a novel technique that allows accurate, interpretable and fast classification." Data mining and knowledge discovery 22, no. 1-2 (2011): 149-182.
#
# [2] Lines, Jason, Luke M. Davis, Jon Hills, and Anthony Bagnall. "A shapelet transform for time series classification." In Proceedings of the 18th ACM SIGKDD international conference on Knowledge discovery and data mining, pp. 289-297. ACM, 2012.
#
# [3] Hills, Jon, Jason Lines, Edgaras Baranauskas, James Mapp, and Anthony Bagnall. "Classification of time series by shapelet transformation." Data Mining and Knowledge Discovery 28, no. 4 (2014): 851-881.
#
# [4] Bostrom, Aaron, and Anthony Bagnall. "Binary shapelet transform for multiclass time series classification." In Transactions on Large-Scale Data-and Knowledge-Centered Systems XXXII, pp. 24-46. Springer, Berlin, Heidelberg, 2017.
#
# ## Example: The Shapelet Transform in sktime
#
# The following workbook demonstrates a full workflow of using the shapelet transform in `sktime` with a `scikit-learn` classifier with the GunPoint problem.

# %%
from sktime.datasets import load_gunpoint
from sktime.transformers.shapelets import ContractedRandomShapeletTransform

train_x, train_y = load_gunpoint(split='TRAIN', return_X_y=True)
test_x, test_y = load_gunpoint(split='TEST', return_X_y=True)

# %%
# How long (in minutes) to extract shapelets for.
# This is a simple lower-bound initially; once time is up, no further shapelets will be assessed
time_limit_in_mins = 1

# The initial number of shapelet candidates to assess per training series. If all series are visited
# and time remains on the contract then another pass of the data will occur 
initial_num_shapelets_per_case = 10

# Whether or not to print on-going information about shapelet extraction. Useful for demo/debugging
verbose = True

st = ContractedRandomShapeletTransform(
    time_limit_in_mins=time_limit_in_mins, 
    initial_num_shapelets_per_case=initial_num_shapelets_per_case, 
    verbose=verbose)
st.fit(train_x, train_y)
# Out:
# visiting series: 22 (#1)
# Candidate finished. 0.496 minutes remaining.
# Candidate finished. 0.492 minutes remaining.
# Candidate finished. 0.487 minutes remaining.
# Candidate finished. 0.482 minutes remaining.
# Candidate finished. 0.476 minutes remaining.
# Candidate finished. 0.473 minutes remaining.
# Candidate finished. 0.469 minutes remaining.
# Candidate finished. 0.466 minutes remaining.
# Candidate finished. 0.46 minutes remaining.
# Candidate finished. 0.455 minutes remaining.
# visiting series: 31 (#2)
# Candidate finished. 0.452 minutes remaining.
# Candidate finished. 0.451 minutes remaining.
# Candidate finished. 0.449 minutes remaining.
# Candidate finished. 0.445 minutes remaining.
# Candidate finished. 0.443 minutes remaining.
# Candidate finished. 0.437 minutes remaining.
# Candidate finished. 0.433 minutes remaining.
# Candidate finished. 0.433 minutes remaining.
# Candidate finished. 0.428 minutes remaining.
# Candidate finished. 0.422 minutes remaining.
# visiting series: 21 (#3)
# Candidate finished. 0.416 minutes remaining.
# Candidate finished. 0.412 minutes remaining.
# Candidate finished. 0.409 minutes remaining.
# Candidate finished. 0.405 minutes remaining.
# Candidate finished. 0.403 minutes remaining.
# Candidate finished. 0.399 minutes remaining.
# Candidate finished. 0.397 minutes remaining.
# Candidate finished. 0.395 minutes remaining.
# Candidate finished. 0.394 minutes remaining.
# Candidate finished. 0.39 minutes remaining.
# visiting series: 25 (#4)
# Candidate finished. 0.387 minutes remaining.
# Candidate finished. 0.384 minutes remaining.
# Candidate finished. 0.38 minutes remaining.
# Candidate finished. 0.38 minutes remaining.
# Candidate finished. 0.377 minutes remaining.
# Candidate finished. 0.373 minutes remaining.
# Candidate finished. 0.369 minutes remaining.
# Candidate finished. 0.365 minutes remaining.
# Candidate finished. 0.362 minutes remaining.
# Candidate finished. 0.358 minutes remaining.
# visiting series: 46 (#5)
# Candidate finished. 0.357 minutes remaining.
# Candidate finished. 0.355 minutes remaining.
# Candidate finished. 0.35 minutes remaining.
# Candidate finished. 0.348 minutes remaining.
# Candidate finished. 0.346 minutes remaining.
# Candidate finished. 0.344 minutes remaining.
# Candidate finished. 0.34 minutes remaining.
# Candidate finished. 0.337 minutes remaining.
# Candidate finished. 0.334 minutes remaining.
# Candidate finished. 0.33 minutes remaining.
# visiting series: 14 (#6)
# Candidate finished. 0.328 minutes remaining.
# Candidate finished. 0.324 minutes remaining.
# Candidate finished. 0.32 minutes remaining.
# Candidate finished. 0.315 minutes remaining.
# Candidate finished. 0.31 minutes remaining.
# Candidate finished. 0.305 minutes remaining.
# Candidate finished. 0.303 minutes remaining.
# Candidate finished. 0.299 minutes remaining.
# Candidate finished. 0.293 minutes remaining.
# Candidate finished. 0.287 minutes remaining.
# visiting series: 27 (#7)
# Candidate finished. 0.281 minutes remaining.
# Candidate finished. 0.275 minutes remaining.
# Candidate finished. 0.269 minutes remaining.
# Candidate finished. 0.267 minutes remaining.
# Candidate finished. 0.262 minutes remaining.
# Candidate finished. 0.257 minutes remaining.
# Candidate finished. 0.251 minutes remaining.
# Candidate finished. 0.248 minutes remaining.
# Candidate finished. 0.245 minutes remaining.
# Candidate finished. 0.243 minutes remaining.
# visiting series: 6 (#8)
# Candidate finished. 0.237 minutes remaining.
# Candidate finished. 0.234 minutes remaining.
# Candidate finished. 0.229 minutes remaining.
# Candidate finished. 0.223 minutes remaining.
# Candidate finished. 0.217 minutes remaining.
# Candidate finished. 0.213 minutes remaining.
# Candidate finished. 0.209 minutes remaining.
# Candidate finished. 0.206 minutes remaining.
# Candidate finished. 0.203 minutes remaining.
# Candidate finished. 0.2 minutes remaining.
# visiting series: 42 (#9)
# Candidate finished. 0.196 minutes remaining.
# Candidate finished. 0.193 minutes remaining.
# Candidate finished. 0.19 minutes remaining.
# Candidate finished. 0.185 minutes remaining.
# Candidate finished. 0.183 minutes remaining.
# Candidate finished. 0.18 minutes remaining.
# Candidate finished. 0.176 minutes remaining.
# Candidate finished. 0.172 minutes remaining.
# Candidate finished. 0.168 minutes remaining.
# Candidate finished. 0.164 minutes remaining.
# visiting series: 37 (#10)
# Candidate finished. 0.162 minutes remaining.
# Candidate finished. 0.158 minutes remaining.
# Candidate finished. 0.155 minutes remaining.
# Candidate finished. 0.152 minutes remaining.
# Candidate finished. 0.15 minutes remaining.
# Candidate finished. 0.144 minutes remaining.
# Candidate finished. 0.14 minutes remaining.
# Candidate finished. 0.134 minutes remaining.
# Candidate finished. 0.131 minutes remaining.
# Candidate finished. 0.126 minutes remaining.
# visiting series: 3 (#11)
# Candidate finished. 0.122 minutes remaining.
# Candidate finished. 0.118 minutes remaining.
# Candidate finished. 0.116 minutes remaining.
# Candidate finished. 0.113 minutes remaining.
# Candidate finished. 0.112 minutes remaining.
# Candidate finished. 0.108 minutes remaining.
# Candidate finished. 0.105 minutes remaining.
# Candidate finished. 0.104 minutes remaining.
# Candidate finished. 0.102 minutes remaining.
# Candidate finished. 0.099 minutes remaining.
# visiting series: 23 (#12)
# Candidate finished. 0.096 minutes remaining.
# Candidate finished. 0.093 minutes remaining.
# Candidate finished. 0.089 minutes remaining.
# Candidate finished. 0.085 minutes remaining.
# Candidate finished. 0.08 minutes remaining.
# Candidate finished. 0.077 minutes remaining.
# Candidate finished. 0.072 minutes remaining.
# Candidate finished. 0.071 minutes remaining.
# Candidate finished. 0.067 minutes remaining.
# Candidate finished. 0.064 minutes remaining.
# visiting series: 26 (#13)
# Candidate finished. 0.061 minutes remaining.
# Candidate finished. 0.057 minutes remaining.
# Candidate finished. 0.056 minutes remaining.
# Candidate finished. 0.053 minutes remaining.
# Candidate finished. 0.049 minutes remaining.
# Candidate finished. 0.045 minutes remaining.
# Candidate finished. 0.041 minutes remaining.
# Candidate finished. 0.039 minutes remaining.
# Candidate finished. 0.035 minutes remaining.
# Candidate finished. 0.032 minutes remaining.
# visiting series: 44 (#14)
# Candidate finished. 0.027 minutes remaining.
# Candidate finished. 0.024 minutes remaining.
# Candidate finished. 0.022 minutes remaining.
# Candidate finished. 0.018 minutes remaining.
# Candidate finished. 0.014 minutes remaining.
# Candidate finished. 0.012 minutes remaining.
# Candidate finished. 0.008 minutes remaining.
# Candidate finished. 0.006 minutes remaining.
# Candidate finished. 0.004 minutes remaining.
# Candidate finished. 0.001 minutes remaining.
# visiting series: 48 (#15)
# time to stop! It's been 0.501 minutes
# ContractedRandomShapeletTransform(dim_to_use=0,
#                  initial_num_shapelets_per_case=None,
#                  max_shapelet_length=inf, min_shapelet_length=3,
#                  num_shapelets_to_trim_to=200, remove_self_similar=True,
#                  seed=0, time_limit_in_mins=None, trim_shapelets=True,
#                  use_binary_info_gain=True, verbose=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# for each extracted shapelet (in descending order of quality/information gain)
for s in st.shapelets[0:5]:

    # summary info about the shapelet 
    print(s)
    
    # plot the series that the shapelet was extracted from 
    plt.plot(
        train_x.iloc[s.series_id,0],
        'gray'
    )
    
    # overlay the shapelet onto the full series
    plt.plot(
        list(range(s.start_pos,(s.start_pos+s.length))),
        train_x.iloc[s.series_id,0][s.start_pos:s.start_pos+s.length],
        'r',
        linewidth=3.0
    )
    plt.show()
# Out:
# series id: 22, start_pos: 21, length: 22, info_gain: 0.674445792128476
# series id: 27, start_pos: 8, length: 48, info_gain: 0.6589398320634585
# series id: 42, start_pos: 3, length: 46, info_gain: 0.6589398320634585
# series id: 42, start_pos: 94, length: 21, info_gain: 0.5471425740964379
# series id: 26, start_pos: 37, length: 37, info_gain: 0.506803759740055

# %%
# for each extracted shapelet (in descending order of quality/information gain)
for i in range(0,5):
    s = st.shapelets[i]
    # summary info about the shapelet 
    print("#"+str(i)+": "+str(s))
    
    # overlay shapelets
    plt.plot(
        list(range(s.start_pos,(s.start_pos+s.length))),
        train_x.iloc[s.series_id,0][s.start_pos:s.start_pos+s.length]
    )

plt.show()
# Out:
# #0: series id: 22, start_pos: 21, length: 22, info_gain: 0.674445792128476
# #1: series id: 27, start_pos: 8, length: 48, info_gain: 0.6589398320634585
# #2: series id: 42, start_pos: 3, length: 46, info_gain: 0.6589398320634585
# #3: series id: 42, start_pos: 94, length: 21, info_gain: 0.5471425740964379
# #4: series id: 26, start_pos: 37, length: 37, info_gain: 0.506803759740055

# %%
import time
import numpy as np
from sktime.datasets import load_gunpoint
from sktime.transformers.shapelets import ContractedRandomShapeletTransform
from sklearn.ensemble.forest import RandomForestClassifier
from sklearn.pipeline import Pipeline

np.random.seed(seed=0)
train_x, train_y = load_gunpoint(split='TRAIN', return_X_y=True)
test_x, test_y = load_gunpoint(split='TEST', return_X_y=True)

# example pipleine with 1 minute time limit
pipeline = Pipeline([
    ('st', ContractedRandomShapeletTransform(time_limit_in_mins=1, initial_num_shapelets_per_case=10, verbose=False)),
    ('rf', RandomForestClassifier()),
])

start = time.time()
pipeline.fit(train_x, train_y)
end_build = time.time()
preds = pipeline.predict(test_x)
end_test = time.time()

print("Results:")
print("Correct:")
correct = sum(preds == test_y)
print("\t"+str(correct)+"/"+str(len(test_y)))
print("\t"+str(correct/len(test_y)))
print("\nTiming:")
print("\tTo build:   "+str(end_build-start)+" secs")
print("\tTo predict: "+str(end_test-end_build)+" secs")
# Out:
# /Users/mloning/.conda/envs/sktime/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Results:
# Correct:
# 	145/150
# 	0.9666666666666667
#
# Timing:
# 	To build:   70.57416987419128 secs
# 	To predict: 30.48314905166626 secs
